# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline 
import matplotlib
matplotlib.rcParams["figure.figsize"] =(20,10)

# %%
df1 = pd.read_csv("rollingsales_queens.csv")
df1.head()
# Out:
#    BOROUGH        NEIGHBORHOOD    BUILDING CLASS CATEGORY  \
# 0        4         AIRPORT JFK  31 COMMERCIAL VACANT LAND
# 1        4  AIRPORT LA GUARDIA    01 ONE FAMILY DWELLINGS
# 2        4  AIRPORT LA GUARDIA    01 ONE FAMILY DWELLINGS
# 3        4  AIRPORT LA GUARDIA    01 ONE FAMILY DWELLINGS
# 4        4  AIRPORT LA GUARDIA    01 ONE FAMILY DWELLINGS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT  EASEMENT BUILDING CLASS AT PRESENT  \
# 0                    4  14260   85       NaN                        V7
# 1                    1    949   21       NaN                        A5
# 2                    1    949   38       NaN                        A5
# 3                    1    976   12       NaN                        A5
# 4                    1    976   50       NaN                        A5
#
#              ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0  N/A ROCKAWAY BLVD              NaN  ...                0.0
# ...
